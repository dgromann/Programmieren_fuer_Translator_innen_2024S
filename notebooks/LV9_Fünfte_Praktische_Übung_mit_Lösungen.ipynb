# %% [markdown]
# <a href="https://colab.research.google.com/github/dgromann/Programmieren_fuer_Translator_innen_2024S/blob/main/notebooks/LV9_Fu%CC%88nfte_Praktische_U%CC%88bung_mit_L%C3%B6sungen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **2024S: Einführung ins Programmieren für Translator:innen, Übung (UE), 340273-1**

# %% [markdown]
# ## **5. Praktische Übung: Das innere eines Language Models**
#
# Dieses Notebook stellt die fünfte praktische Übung vor, die dazu dient die interne Darstellung von Sprache in einem Language Model kennenzulernen.
#
# Dazu müssen erst wieder die erforderlichen Programmbibliotheken installiert werden.

# %%
# !pip install transformers
# !pip install sentencepiece
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.41.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.14.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.6.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (0.1.99)

# %% [markdown]
# Dann laden wir das erste Modelle, welches ein mehrsprachiges vortrainiertes Sprachmodell names XLM-RoBERTa (XLM-R) in der kleinen Variante `small` ist.

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("google-t5/t5-small")

# %% [markdown]
# Nun können Sie das intern dargestellte Vokabular des Modells mithilfe der Funktion `tokenizer.get_vocab()` ausgeben lassen. Bedenken Sie, dass der Tokenizer sowohl Tokens als auch IDs speichert. Wir sind hier nur an Tokens interessiert.

# %% [markdown]
# In dieser Form der Tokenisierung werden alle Tokens, die den Beginn eines Wortes darstellen mit einem Unterstrich versehen. Tokens ohne Unterstrich stellen somit die Weiterführung eines Wortes dar.
#
# Um das besser darzustellen, führen Sie bitte eine Tokenisierung auf dem folgenden Beipsielsatz durch, indem Sie einfach

# %%
example_sentence = "Diese Übung erlaubt es mir die innere Darstellung des Vokabulars eines Sprachmodells zu analysieren."
sentence_tokenized = tokenizer.tokenize(example_sentence)
print(sentence_tokenized)
# Out:
# ['▁Diese', '▁Übung', '▁erlaubt', '▁', 'e', 's', '▁mir', '▁die', '▁inner', 'e', '▁Darstellung', '▁des', '▁Vo', 'ka', 'b', 'ular', 's', '▁eine', 's', '▁Sprach', 'modell', 's', '▁zu', '▁analys', 'ieren', '.']

# %% [markdown]
# 👋 ⚒ **Aufgabe** 👋 ⚒ <br>
# Beantworten Sie mithilfe der Funktion `tokenizer.get_vocab()` die folgenden Fragen in der nachstehenden Code-Zelle direkt als Python-Code und -Ausgabe:
#
#
#
# *   Welcher Datentyp wird von der Funktion `tokenizer.get_vocab()` zurückgegeben? Geben Sie den Datentyp aus.
# *   Wie viele Tokens sind insgesamt im Modell gespeichert?
# *   Wenn die Tokens als Liste dargestellt werden, welcher Token ist an Position 300 zu finden?

# %%
# Fügen Sie hier Ihren Code hier ein
vocabulary = tokenizer.get_vocab()

#Welcher Datentyp
print(type(vocabulary))

#Wie viele Tokens
print(len(vocabulary))

# Tokens als Liste und Ausgabe von Position 300 (Index 299)
print(list(vocabulary.keys())[299])
# Out:
# <class 'dict'>
# 32100
# ▁humiliat

# %% [markdown]
# 👋 ⚒ **Aufgabe** 👋 ⚒ <br>
# Erstellen Sie nun eine Funktion, welche alle Tokens, die nur aus einem Zeichen bestehen, zurückgibt.
#
# Geben Sie jeweils 30 Tokens aus nur einem Zeichen pro Zeile aus. Das können Sie erreichen, indem Sie eine Liste erstellen, die dann alle 30 Tokens bestehend aus nur einem Zeichen ausgegeben wird, auf eine leere Liste zurückgesetzt wird und wieder von neuem mit jeweils 30 Tokens versehen wird.

# %%
# Fügen Sie hier Ihren Code hier ein
token_list = []
for token in vocabulary.keys():
  token = token.replace("▁", "")
  if len(token) == 1:
    token_list.append(token)
  if len(token_list) == 30:
    print(token_list)
    token_list = []
# Out:
# ['U', 'Z', '€', '4', 'ä', '=', 'ß', '(', 'S', 'á', '—', 'C', '|', '0', '“', 'à', '’', '!', '»', 'G', 'в', '_', ']', 'O', 'ă', '£', 'H', 'A', 'P', 'F']
# ['a', '7', 'p', 's', '?', '£', '3', 'C', '•', '9', 'V', '»', '.', '«', 'w', '7', 'N', 'ş', 'T', 'с', '«', 'д', '1', '°', 'ç', '‘', ')', '$', 'B', 'k']
# ['y', '(', '|', 'о', 'ţ', 'S', 'Q', 'n', 'M', 'W', 'm', 'E', 'в', '®', '€', '+', '•', '‘', 'R', 'â', 'N', '#', '”', 'D', '"', 'R', 'û', 'ț', '/', '9']
# [';', '>', 'т', 'G', 'Z', '$', ',', '[', '"', 'É', 'H', 'D', 'к', 'h', 'K', '5', '\xad', 'F', '2', '[', 'W', "'", '“', 'è', '6', '%', 'v', '5', 'g', 'Î']
# ['=', 'B', 'X', 'Y', 'î', 'Q', 'у', 'A', '„', 'i', '2', '*', 'с', 'р', 'é', 'x', '&', 'c', 'J', 'ê', '′', '–', 'K', '-', 'u', 'а', 'и', 'ô', 'н', 'е']
# ['л', 'e', 'ö', 'b', 'j', 'O', 'J', 'V', '@', 'L', 'r', 'Ü', '@', '6', 'f', 'U', '1', 'L', '*', 'E', 'I', '8', '8', 'ü', '+', 'l', 'o', '4', 'É', '3']

# %% [markdown]
# 👋 ⚒ **Aufgabe** 👋 ⚒ <br>
# Mithilfe von WordNet werden wir nun eine Schätzung der englischen Wörter in der Liste der Tokens berechnen.
#
# Dazu müssen erst wieder die erforderlichen Programmbibliotheken installiert werden und WordNet geladen werden.

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.4)

# %%
import nltk
from nltk.corpus import wordnet

nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %% [markdown]
# Schreiben Sie dazu eine Funktion, welche überprüft ob für ein Token ein Synset in WordNet gefunden wird oder nicht (`wordnet.synsets(token)`). Zählen Sie dabei wie viele Tokens ein Synset aufweisen und berechnen Sie die Prozent dieser Anzahl im Vergleich zur Gesamtanzahl der Tokens.
#
# Bitte beachten Sie, dass der vorangehende Unterstrich _ bei den Tokens entfernt werden sollte, nicht jedoch jedes Token einen Unterstrich hat.  Achten Sie bitte auch darauf, dass der Unterstrich eine ganz eigene Encodierung hat und direkt aus der Ausgabe des Vokabulars kopiert werden sollte (nicht als Unterstrich auf der Tastatur eingegeben werden sollte).
#
# Wie unterscheidet sich die Prozentzahl der gefundenen Tokens mit oder ohne Entfernung des Unterstrichs?

# %%
# Fügen Sie hier Ihren Code hier ein
def find_english_tokens_with_underscore(vocab):
  tokens_in_wordnet = []
  for token in vocab.keys():
    if wordnet.synsets(token):
      tokens_in_wordnet.append(token)
  return tokens_in_wordnet

def find_english_tokens_without_underscore(vocab):
  tokens_in_wordnet = []
  for token in vocab.keys():
    token = token.replace("▁", "")
    if wordnet.synsets(token):
      tokens_in_wordnet.append(token)
  return tokens_in_wordnet

english_with_underscore = find_english_tokens_with_underscore(vocabulary)
english_without_underscore = find_english_tokens_without_underscore(vocabulary)

print(f"Die Gesamtanzahl der Tokens in WordNet ohne Entfernung des Unterstrichs beträgt {round((len(english_with_underscore)/len(vocabulary))*100,2)}% aller Tokens.")
print(f"Diese sind {english_with_underscore} \n")
print(f"Die Gesamtanzahl der Tokens in WordNet mit Entfernung des Unterstrichs beträgt {round((len(english_without_underscore)/len(vocabulary))*100,2)}% aller Tokens.")
print(f"Diese sind {english_without_underscore}")
# Out:
# Die Gesamtanzahl der Tokens in WordNet ohne Entfernung des Unterstrichs beträgt 13.31% aller Tokens.
# Diese sind ['Online', 'gan', 'preferably', 'Download', 'braking', 'Hi', 'Mon', 'South', 'turn', 'India', 'break', 'reveals', 'landed', 'oder', 'OFF', 'mat', 'graf', 'TED', 'ether', 'beaten', 'best', 'original', '78', 'U', 'hull', 'yahoo', 'National', 'auto', 'Norm', 'ORS', 'car', 'cord', 'topic', 'lock', 'boy', 'Game', 'itch', 'page', 'associated', 'hill', 'except', 'tell', 'europa', '30', 'illustrating', 'VS', 'stroke', 'lands', 'harm', 'image', 'range', 'NGOs', 'Govern', 'spotted', 'Inter', 'printed', 'day', 'dragging', 'stacked', 'incredibly', 'strained', 'Advisory', 'cier', 'som', 'Z', 'rounded', 'RU', 'chemical', 'bonded', 'Info', 'ranging', 'Level', 'uploads', 'ALT', 'revealing', 'stick', 'De', 'movers', 'commerce', 'vases', 'environ', 'riel', 'FIN', 'dream', 'cid', 'aspiring', 'protein', 'together', 'uer', 'nett', 'bib', 'determining', 'heir', 'trade', 'grew', 'Runner', 'being', 'governmental', 'blood', 'are', 'aries', 'NB', 'bog', 'high', 'supplementary', 'HAM', 'le', 'think', 'positioned', 'door', 'fund', 'lan', 'brow', 'bacterial', 'LIN', 'ious', 'nourishing', 'verse', 'essay', 'SSA', 'recalled', 'NYSE', 'Alb', 'Basically', 'varsity', 'ides', 'demonstrates', 'Account', 'acted', 'Point', 'NO', 'machining', 'pinned', 'TS', 'wall', 'cup', 'Quite', 'rink', 'GU', 'MAT', 'cum', 'calculating', 'WAY', 'ANA', 'cas', 'situation', 'Lab', 'add', 'Euro', 'FIT', 'synthesis', 'max', 'affirmed', 'sign', 'ney', 'AM', 'plasm', 'March', '4', 'ki', 'accustomed', 'rest', 'specialised', 'plus', 'tec', 'up', 'Occupational', 'grin', 'CAS', 'cession', 'CENT', 'headquartered', 'blog', 'John', 'nov', 'AGE', 'weight', 'maladies', 'canceled', 'ambiance', 'claim', 'millennial', 'Accord', 'suing', 'eck', 'admired', 'RNA', 'welcher', 'pens', 'lox', 'conscious', 'Mainland', 'ford', 'Ru', 'Luckily', 'rent', 'UK', 'CIA', 'fix', 'AIS', 'pharma', 'stepping', 'zen', 'bis', 'First', 'bundled', 'hole', 'regulating', 'VENT', 'camp', 'accentuate', 'video', 'hereby', 'spans', 'rum', 'anti', 'lier', 'risk', 'MI', 'author', 'AIN', 'PT', 'subsequently', 'LE', 'fortunately', 'interest', 'positive', 'characterization', 'partisan', 'historic', 'Stylish', 'FT', 'sprung', 'tag', 'Sullivan', 'gui', 'effective', 'prestigious', 'thereby', 'retrieved', 'tail', 'GC', 'defender', 'Master', 'pvc', 'claiming', 'lit', 'card', 'Map', 'aims', 'argent', 'koch', 'large', 'lid', 'starring', 'habitude', 'hunt', 'able', 'vest', 'Managing', 'CI', 'nova', 'demand', 'Australia', 'MAR', 'S', 'col', 'Fig', 'ignoring', 'fish', 'mann', 'final', 'abused', 'bit', 'function', 'Identify', 'fusion', 'LINE', 'excluding', 'frequent', 'ruled', 'rust', '94', 'midst', 'despite', 'Trader', 'mus', 'sweeping', '48', 'Nonetheless', 'coding', 'DE', 'Considering', 'chen', 'finder', 'mon', 'noc', 'wishing', 'Group', 'fewer', 'it', 'walker', 'ED', 'complemented', 'cro', 'funk', 'Result', 'git', 'Some', 'country', 'lip', 'IO', 'Integrated', 'Vanity', 'melted', 'rise', 'demonstrating', '100', 'Revelation', 'varies', 'commanded', 'th', 'attend', 'American', 'black', 'RAT', 'Sodium', 'Rather', 'urging', 'guer', 'glob', 'Mod', 'weder', 'cloud', 'strand', 'optimisation', 'rail', 'guiding', 'call', 'Democrat', 'C', 'between', 'knowingly', 'dated', 'Ex', 'nozzle', 'fuses', 'abel', 'SET', 'vacancy', 'graphic', 'accessed', 'drywall', '96', 'LR', 'Up', 'CIS', 'Bar', 'right', 'current', 'azo', 'cherished', 'safe', 'pristine', 'Obviously', 'Great', 'Archived', 'boot', 'aide', 'recommending', 'lowed', 'gab', 'EL', 'scholarly', 'pond', 'fidelity', 'arch', 'colored', 'Rob', 'UN', 'ledge', '0', 'hum', 'scanned', 'raft', 'panel', 'fern', 'assembling', 'CAD', 'Please', 'professional', 'armed', 'energy', 'Applied', 'Stunning', 'bank', 'WOOD', 'unused', 'Ultimately', 'leg', 'undergoing', 'Connect', 'Radio', 'tar', 'cyan', 'mailed', 'assemblage', 'GIN', 'trip', 'hesitant', '99', 'surfacing', 'rig', 'leger', 'Top', 'problem', 'ACTION', 'nd', 'dale', 'pus', 'smoked', 'voted', 'Association', 'censor', 'annual', 'courtesy', 'Immedia ...
#
# Die Gesamtanzahl der Tokens in WordNet mit Entfernung des Unterstrichs beträgt 57.77% aller Tokens.
# Diese sind ['used', 'specified', 'Aquarium', 'Online', 'SA', 'Cop', 'response', 'govern', 'archive', 'gan', 'bronze', 'webpage', 'nervous', 'preferably', 'displays', 'Carol', 'manufacturers', 'fifty', 'lot', 'Logistics', 'Download', 'recipient', 'survey', 'Studios', 'precision', 'Got', 'Columbus', 'employed', 'braking', 'Hi', 'Finger', 'sending', 'proficient', 'Avengers', 'pulled', 'emblem', 'Fourth', 'Mon', 'South', 'pocket', 'turn', 'Tom', 'character', 'often', 'shield', 'Mutual', 'platform', 'providers', 'got', 'cells', 'India', 'burglar', 'amazing', 'break', 'maternal', 'separation', 'personalized', 'Leeds', 'bunk', 'Vertical', 'connector', 'employment', 'reveals', 'landed', 'oder', 'discovering', 'vomiting', 'include', 'entities', 'illuminate', 'OFF', 'mat', 'graf', 'Kosovo', 'population', 'ubiquitous', 'apple', 'TED', 'arrest', 'ether', 'Pool', 'blocks', 'glue', 'beaten', 'Secure', 'best', 'certainly', 'reactions', 'Spencer', 'brut', 'boycott', 'duties', 'original', 'seeds', 'Keller', 'chute', 'Portrait', '78', 'candidature', 'U', 'summer', 'Possible', 'hull', 'permission', 'prosecution', 'Resort', 'subsequent', 'yahoo', 'Results', 'National', 'auto', 'CD', 'kindergarten', 'Norm', 'an', 'Matt', 'utilize', 'Type', 'Drink', 'ORS', 'sciences', 'width', 'sodium', 'Combat', 'prevail', 'Yellow', 'car', 'elevator', 'brutal', 'zones', 'fixed', 'guides', 'Bestseller', 'fade', 'cord', 'neat', 'images', 'casserole', 'dollars', 'enthusiasts', 'hart', 'inhabit', 'topic', 'meteor', 'graduate', 'Nobel', 'Index', 'tremendous', 'head', 'historic', 'lock', 'boy', 'Sind', 'Game', 'travelling', 'gens', 'itch', 'page', 'Memphis', 'flooding', 'Affordable', 'associated', 'hill', 'even', 'helps', 'rude', 'crossed', 'except', 'depart', 'tell', 'europa', 'booth', 'Plumber', 'colored', 'users', '30', 'handmade', 'illustrating', 'Competitive', 'VS', 'requirements', 'cleaner', 'flower', 'Tampa', 'Kat', 'beating', 'cleanse', 'reprise', 'bless', 'stroke', 'scholar', 'Terry', 'Rack', 'lands', 'scenery', 'conveyor', 'garnish', 'harm', 'clerk', 'configured', 'image', 'government', 'edges', 'administrative', 'gray', 'Howard', 'altered', 'demand', 'regards', 'didactic', 'opportunity', 'Th', 'raising', 'ASAP', 'range', 'NGOs', 'Govern', 'Pal', 'fragment', 'bacon', 'traffic', 'procedure', 'Yet', 'spotted', 'gracious', 'Inter', 'conversion', 'printed', 'closer', 'hobby', 'day', 'Decision', 'dragging', 'influent', 'stacked', 'printable', 'taken', 'positioning', 'survivors', 'Roma', 'Don', 'Ride', 'officially', 'Lounge', 'Brush', 'Near', 'hide', 'Experimental', 'incredibly', 'strained', 'Advisory', 'mother', 'fees', 'cier', 'som', 'parties', 'Z', 'justified', 'favorite', 'shark', 'arts', 'Adrian', 'menace', 'Above', 'rounded', 'RU', 'mayor', 'Shower', 'mourn', 'successfully', 'pediatric', 'print', 'means', 'fault', 'chemical', 'assigned', 'bonded', 'Info', 'scallop', 'ranging', 'authorities', 'Aviation', 'believe', 'complaint', 'society', 'biking', 'meals', 'Level', 'legume', 'Sachsen', 'bankruptcy', 'correlation', 'foil', 'Position', 'Website', 'Virtu', 'uploads', 'spa', 'shout', 'Course', 'unknown', 'massacre', 'technologies', 'theft', 'heroin', 'adventure', 'platter', 'targeting', 'Election', '26', 'introduced', 'disastrous', 'bat', 'suicide', 'style', 'ALT', 'revealing', 'genome', 'stick', 'Bluff', 'Skills', 'De', 'Minor', 'Muslims', 'Al', 'movers', 'commerce', 'vocabulary', 'pipes', 'Neo', 'shading', 'vases', 'kitten', 'Dim', 'consumed', 'environ', 'comprehension', 'accompany', 'gib', 'Industry', 'needle', 'bought', 'lodging', 'expenditure', 'actor', 'dive', 'fastest', 'oasis', 'increment', 'riel', 'space', 'FIN', 'dream', 'Boys', 'correspondent', 'manufacturing', 'quick', 'thick', 'chief', 'hair', 'Gu', 'Interstate', 'regulate', 'challenge', 'Chance', 'cid', 'schemes', 'aspiring', 'Black', 'protein', 'together', 'improper', 'optimistic', 'Alarm', 'uer', 'shortly', 'recipients', 'Reserve', 'qualification', 'nett', 'grind', 'discharge', 'bib', 'implant', 'd ...
